# %% [markdown]
# <a href="https://colab.research.google.com/github/whoops88/NLP_project_Trump_rallies/blob/main/MNIST_my_first_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании вам предстоит обучить модель классификации рукописных цифр на Tensorflow.
#
# Важным дополнительным требованием будет сохранение чекпоинтов на ваш гугл диск (не переживайтеЖ ниже будут подсказки, как это сделать). Это пригодится вам в дальнейшем при обучении более сложных моделей, на случай потери данных при неожиданном отключении Colab.

# %%
import tensorflow as tf
print(tf.__version__)
from google.colab import drive
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2.4.1

# %% [markdown]
# ####Вспомогательный код

# %%
#@title 
def show_mnist(images, labels, predicted_labels=None):
    plt.figure(figsize=(10,10))
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.gray)
        if predicted_labels is not None:
            title_obj = plt.title(f"Real: {labels[i]}. Pred: {predicted_labels[i]}")
            if labels[i] != predicted_labels[i]:
                plt.setp(title_obj, color='r')
        else:
            plt.title(f"Real label: {labels[i]}")

def show_progress(history: dict):
    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(1,2,1)    
    plt.plot(history["accuracy"],label='train accuracy')
    plt.plot(history["val_accuracy"], label='test accuracy')
    ax2 = plt.subplot(1,2,2)
    plt.plot(history["loss"],label='train_loss')
    plt.plot(history["val_loss"],label='test_loss')
    
    ax1.legend(loc='best')
    ax2.legend(loc='best')
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Загрузка данных

# %%
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

show_mnist(x_train, y_train)
x_train = x_train.reshape((-1, 28*28)) # вытянули каждую картинку в вектор
x_test = x_test.reshape((-1, 28*28))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# прикрепим ваш гугл диск к виртуальной машине
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Путь до вашего гугл диска скорее всего выглядит так: /content/drive/My Drive/
# если эта клетка вызывает ошибку, 
# измените путь согласно ! ls "/content/drive/"

path = Path("/content/drive/My Drive/Skillbox/model_1")
path.mkdir(exist_ok=True, parents=True) # папка создается на вашем гугл диске. вместе с "родителями"
assert path.exists()
cpt_filename = "best_checkpoint.hdf5"  
cpt_path =str(path / cpt_filename)
# После выполнения этой клетки, в вашем гугл диске должна создаться папка: Skillbox/model_1
# убедитесь в этом

# %% [markdown]
# А весь код ниже вы реализуете самостоятельно! Вы уже к этому готовы :)
# Требования к модели:
# 1. Точность на тестовой части выборки >96%
# 2. Чекпоинт модели с лучшими параметрами должен быть сохранен у вас на гугл диске
# 3. Объект history, который получается из model.fit(...) должен содержать значения лосса и accuracy для трейна и теста

# %%
# < YOUR CODE STARTS HERE >
model = tf.keras.Sequential()

model.add(tf.keras.layers.Dense(64, input_shape=(784,), activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metric = 'val_accuracy'
checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor=metric,
                                                save_best_only=True, mode='max',
                                                verbose=1)

model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

history = model.fit(x=x_train, y=y_train, epochs=30, verbose=1, batch_size=64, 
          validation_data=(x_test, y_test), callbacks=[checkpoint])

# < YOUR CODE ENDS HERE >
# Out:
# Epoch 1/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5350 - accuracy: 0.8453 - val_loss: 0.1461 - val_accuracy: 0.9525
#
# Epoch 00001: val_accuracy improved from -inf to 0.95250, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 2/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1270 - accuracy: 0.9624 - val_loss: 0.1065 - val_accuracy: 0.9678
#
# Epoch 00002: val_accuracy improved from 0.95250 to 0.96780, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 3/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0855 - accuracy: 0.9729 - val_loss: 0.1061 - val_accuracy: 0.9689
#
# Epoch 00003: val_accuracy improved from 0.96780 to 0.96890, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 4/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0695 - accuracy: 0.9778 - val_loss: 0.1000 - val_accuracy: 0.9674
#
# Epoch 00004: val_accuracy did not improve from 0.96890
# Epoch 5/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0513 - accuracy: 0.9835 - val_loss: 0.0848 - val_accuracy: 0.9740
#
# Epoch 00005: val_accuracy improved from 0.96890 to 0.97400, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 6/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0428 - accuracy: 0.9863 - val_loss: 0.1075 - val_accuracy: 0.9679
#
# Epoch 00006: val_accuracy did not improve from 0.97400
# Epoch 7/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0377 - accuracy: 0.9878 - val_loss: 0.1002 - val_accuracy: 0.9709
#
# Epoch 00007: val_accuracy did not improve from 0.97400
# Epoch 8/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0318 - accuracy: 0.9898 - val_loss: 0.0961 - val_accuracy: 0.9739
#
# Epoch 00008: val_accuracy did not improve from 0.97400
# Epoch 9/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.0872 - val_accuracy: 0.9761
#
# Epoch 00009: val_accuracy improved from 0.97400 to 0.97610, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 10/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.0869 - val_accuracy: 0.9767
#
# Epoch 00010: val_accuracy improved from 0.97610 to 0.97670, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 11/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0984 - val_accuracy: 0.9766
#
# Epoch 00011: val_accuracy did not improve from 0.97670
# Epoch 12/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.1107 - val_accuracy: 0.9730
#
# Epoch 00012: val_accuracy did not improve from 0.97670
# Epoch 13/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.1050 - val_accuracy: 0.9760
#
# Epoch 00013: val_accuracy did not improve from 0.97670
# Epoch 14/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.1261 - val_accuracy: 0.9710
#
# Epoch 00014: val_accuracy did not improve from 0.97670
# Epoch 15/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.1050 - val_accuracy: 0.9754
#
# Epoch 00015: val_accuracy did not improve from 0.97670
# Epoch 16/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.1327 - val_accuracy: 0.9729
#
# Epoch 00016: val_accuracy did not improve from 0.97670
# Epoch 17/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.1152 - val_accuracy: 0.9770
#
# Epoch 00017: val_accuracy improved from 0.97670 to 0.97700, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 18/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.1165 - val_accuracy: 0.9763
#
# Epoch 00018: val_accuracy did not improve from 0.97700
# Epoch 19/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.1093 - val_accuracy: 0.9766
#
# Epoch 00019: val_accuracy did not improve from 0.97700
# Epoch 20/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.1088 - val_accuracy: 0.9779
#
# Epoch 00020: val_accuracy improved from 0.97700 to 0.97790, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 21/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.1058 - val_accuracy: 0.9783
#
# Epoch 00021: val_accuracy improved from 0.97790 to 0.97830, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 22/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.1305 - val_accuracy: 0.9748
#
# Epoch 00022: val_accuracy did not improve from 0.97830
# Epoch 23/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.1269 - val_accuracy: 0.9764
#
# Epoch 00023: val_accuracy did not improve from 0.97830
# Epoch 24/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.1290 - val_accuracy: 0.9784
#
# Epoch 00024: val_accuracy improved from 0.97830 to 0.97840, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 25/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.1418 - val_accuracy: 0.9770
#
# Epoch 00025: val_accuracy did not improve from 0.97840
# Epoch 26/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.1420 - val_accuracy: 0.9738
#
# Epoch 00026: val_accuracy did not improve from 0.97840
# Epoch 27/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.1295 - val_accuracy: 0.9769
#
# Epoch 00027: val_accuracy did not improve from 0.97840
# Epoch 28/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.1381 - val_accuracy: 0.9766
#
# Epoch 00028: val_accuracy did not improve from 0.97840
# Epoch 29/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1248 - val_accuracy: 0.9790
#
# Epoch 00029: val_accuracy improved from 0.97840 to 0.97900, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 30/30
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.1334 - val_accuracy: 0.9768
#
# Epoch 00030: val_accuracy did not improve from 0.97900

# %%
assert len(list(path.glob("*"))) != 0, f"Checkpoint dir {path}"
assert "accuracy" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
assert "val_accuracy" in history.history, "Please, provide validation_data in model.fit."
assert np.max(history.history["val_accuracy"]) > 0.95, "Validation accuracy must be more than 0.95"
print("Training tests passed")
# Out:
# Training tests passed

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Давайте посмотрим на графики обучения:

# %%
show_progress(history.history)

# %% [markdown]
# А теперь перейдем к загрузке модели. Если все реализовано правильно, то код ниже должен сработать без ошибок:

# %%
restored_model = tf.keras.models.load_model(cpt_path)
loss, acc = restored_model.evaluate(x_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
assert acc > 0.96
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1248 - accuracy: 0.9790
# Accuracy of restored model 97.90%

# %% [markdown]
# И, наконец, можно сравнить предсказания с реальными классами (с такой точностью найти ошибку будет сложно):

# %%
predicted_labels = restored_model.predict_classes(x_test)
idxs = np.random.choice(np.arange(len(x_test)), 16, replace=False)
show_mnist(x_test[idxs].reshape((-1, 28, 28)), y_test[idxs], predicted_labels[idxs])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
